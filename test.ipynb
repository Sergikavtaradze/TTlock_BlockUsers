# %%
base = "14 - 69 რამაზ გილგემიანი"
#base.replace('-','').isdigit()
print(base)


base_2 = "60/64 ალექსანდრე"
#base_2.replace('/','').isdigit()
print(base_2)

if base_2.replace('/','').isdigit() or base_2.replace('/','').isdigit():
    if '/' not in base_2:
        base = str(int(base_2))
        print(base)
# Out:
# 14 - 69 რამაზ გილგემიანი
# 60/64 ალექსანდრე
